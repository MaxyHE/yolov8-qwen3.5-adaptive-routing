# %%
import ultralytics
import xml.etree.ElementTree as ET                                                                                      
import os

classes = ['aeroplane','bicycle','bird','boat','bottle','bus','car','cat',
         'chair','cow','diningtable','dog','horse','motorbike','person',
         'pottedplant','sheep','sofa','train','tvmonitor']

def convert_box(size, box):
  dw, dh = 1./size[0], 1./size[1]
  x = (box[0]+box[1])/2 * dw
  y = (box[2]+box[3])/2 * dh
  w = (box[1]-box[0]) * dw
  h = (box[3]-box[2]) * dh
  return x, y, w, h

anno_path = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/Annotations'
label_path = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/labels'
os.makedirs(label_path, exist_ok=True)

for xml_file in os.listdir(anno_path):
  if not xml_file.endswith('.xml'):
      continue
  tree = ET.parse(os.path.join(anno_path, xml_file))
  root = tree.getroot()
  size = root.find('size')
  w = int(size.find('width').text)
  h = int(size.find('height').text)

  txt_file = xml_file.replace('.xml', '.txt')
  with open(os.path.join(label_path, txt_file), 'w') as f:
      for obj in root.iter('object'):
          cls = obj.find('name').text
          if cls not in classes:
              continue
          cls_id = classes.index(cls)
          bb = obj.find('bndbox')
          box = (float(bb.find('xmin').text), float(bb.find('xmax').text),
                 float(bb.find('ymin').text), float(bb.find('ymax').text))
          x, y, w_n, h_n = convert_box((w,h), box)
          f.write(f"{cls_id} {x:.6f} {y:.6f} {w_n:.6f} {h_n:.6f}\n")

print(f"转换完成，共{len(os.listdir(label_path))}个标签文件")
# Out:
# 转换完成，共17125个标签文件

# %%
import os
print(os.listdir('/home/hejiening/2026/yolo/VOCdevkit/VOC2012'))
# Out:
# ['SegmentationClass', 'labels', 'JPEGImages.cache', 'Annotations', 'SegmentationObject', 'ImageSets', 'JPEGImages']

# %%
print(os.listdir('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/ImageSets/Main'))
# Out:
# ['aeroplane_train.txt', 'tvmonitor_train.txt', 'sofa_trainval.txt', 'person_val.txt', 'bus_trainval.txt', 'cat_val.txt', 'pottedplant_train.txt', 'bird_train.txt', 'dog_train.txt', 'trainval.txt', 'bicycle_val.txt', 'sofa_train.txt', 'person_train.txt', 'bird_trainval.txt', 'sheep_trainval.txt', 'horse_val.txt', 'chair_val.txt', 'train_val.txt', 'bus_train.txt', 'chair_trainval.txt', 'train.txt', 'train_train.txt', 'horse_trainval.txt', 'bottle_val.txt', 'sheep_val.txt', 'chair_train.txt', 'motorbike_train.txt', 'tvmonitor_val.txt', 'bicycle_trainval.txt', 'bottle_train.txt', 'person_trainval.txt', 'dog_trainval.txt', 'sheep_train.txt', 'diningtable_train.txt', 'bus_val.txt', 'car_val.txt', 'diningtable_val.txt', 'car_trainval.txt', 'aeroplane_trainval.txt', 'cow_val.txt', 'cow_trainval.txt', 'aeroplane_val.txt', 'pottedplant_val.txt', 'train_trainval.txt', 'boat_train.txt', 'dog_val.txt', 'bicycle_train.txt', 'sofa_val.txt', 'bottle_trainval.txt', 'cat_trainval.txt', 'horse_train.tx
# ...

# %%
import os                                                                                                             
base = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012'

for split in ['train', 'val']:
  with open(f'{base}/ImageSets/Main/{split}.txt') as f:
      ids = f.read().strip().split()
  with open(f'{base}/{split}_images.txt', 'w') as f:
      for id in ids:
          f.write(f'{base}/JPEGImages/{id}.jpg\n')
  print(f'{split}: {len(ids)}张')
# Out:
# train: 5717张
# val: 5823张

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.train(
  data='/home/hejiening/2026/yolo/VOC2012.yaml',
  epochs=50,
  imgsz=640,
  batch=16,
  device=0
)
# Out:
# Ultralytics 8.4.36 🚀 Python-3.8.20 torch-1.9.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
from ultralytics import YOLO                                                                                            
import traceback
                                                                                                                      
try:                                                                                                                e
  model = YOLO('yolov8n.pt')
  results = model.train(
      data='/home/hejiening/2026/yolo/VOC2012.yaml',
      epochs=1,
      imgsz=640,
      batch=16,
      device=0
  )
except Exception as e:
  print(traceback.format_exc())
# Out:
#   Cell In[11], line 5
#     model = YOLO('yolov8n.pt')
#     ^
# IndentationError: unexpected indent

# %%
from ultralytics import YOLO                                                                                            
model = YOLO('yolov8n.pt')
results = model.train(data='/home/hejiening/2026/yolo/VOC2012.yaml', epochs=1, imgsz=640, batch=16, device=0)
# Out:
# Ultralytics 8.4.36 🚀 Python-3.8.20 torch-1.9.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
import os
imgs = os.listdir('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/JPEGImages')[:3]
labels = os.listdir('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/labels')[:3]
print("图片:", imgs)
print("标签:", labels)
# Out:
# 图片: ['2011_000770.jpg', '2011_005321.jpg', '2011_000806.jpg']
# 标签: ['2011_001259.txt', '2010_006364.txt', '2008_006128.txt']

# %%
label_path = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/labels/2011_000770.txt'
print(os.path.exists(label_path))
# Out:
# True

# %%
import os
cache1 = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/JPEGImages.cache'
if os.path.exists(cache1):
  os.remove(cache1)
  print("cache已删除")

model = YOLO('yolov8n.pt')
results = model.train(data='/home/hejiening/2026/yolo/VOC2012.yaml', epochs=1, imgsz=640, batch=16, device=0)
# Out:
# cache已删除
# Ultralytics 8.4.36 🚀 Python-3.8.20 torch-1.9.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
with open('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/labels/2011_000770.txt') as f:      
    print(f.read())
# Out:
# 13 0.495946 0.423000 0.672973 0.766000
# 13 0.597297 0.716000 0.194595 0.100000

# %%
import os                                                                                                               
base = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012'                                                                
for f in os.listdir(base):
  if 'cache' in f.lower():
      print(f)
# Out:
# JPEGImages.cache

# %%
import os                                                                                                               
os.remove('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/JPEGImages.cache')
print("删除成功")

cache2 = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/train_images.cache'
cache3 = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/val_images.cache'
for c in [cache2, cache3]:
  if os.path.exists(c):
      os.remove(c)
      print(f"删除{c}")
  else:
      print(f"不存在{c}")
# Out:
# 删除成功
# 不存在/home/hejiening/2026/yolo/VOCdevkit/VOC2012/train_images.cache
# 不存在/home/hejiening/2026/yolo/VOCdevkit/VOC2012/val_images.cache

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/home/hejiening/2026/yolo/VOC2012.yaml', epochs=1, imgsz=640, batch=16, device=0)
# Out:
# Ultralytics 8.4.36 🚀 Python-3.8.20 torch-1.9.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
import os
import shutil

base = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012'

# 建标准目录
os.makedirs(f'{base}/images/train', exist_ok=True)
os.makedirs(f'{base}/images/val', exist_ok=True)
os.makedirs(f'{base}/labels/train', exist_ok=True)
os.makedirs(f'{base}/labels/val', exist_ok=True)

# 读取train/val列表
for split in ['train', 'val']:
  with open(f'{base}/ImageSets/Main/{split}.txt') as f:
      ids = f.read().strip().split()
  for id in ids:
      # 复制图片
      src_img = f'{base}/JPEGImages/{id}.jpg'
      dst_img = f'{base}/images/{split}/{id}.jpg'
      if os.path.exists(src_img):
          shutil.copy2(src_img, dst_img)
      # 复制标签
      src_lbl = f'{base}/labels/{id}.txt'
      dst_lbl = f'{base}/labels/{split}/{id}.txt'
      if os.path.exists(src_lbl):
          shutil.copy2(src_lbl, dst_lbl)
  print(f'{split}完成')
# Out:
# train完成
# val完成

# %%
import os                                                                                                               
os.remove('/home/hejiening/2026/yolo/VOCdevkit/VOC2012/JPEGImages.cache')
print("删除成功")

cache2 = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/train_images.cache'
cache3 = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/val_images.cache'
for c in [cache2, cache3]:
  if os.path.exists(c):
      os.remove(c)
      print(f"删除{c}")
  else:
      print(f"不存在{c}")
# Out:
# 删除成功
# 不存在/home/hejiening/2026/yolo/VOCdevkit/VOC2012/train_images.cache
# 不存在/home/hejiening/2026/yolo/VOCdevkit/VOC2012/val_images.cache

# %%
import os
cache = '/home/hejiening/2026/yolo/VOCdevkit/VOC2012/JPEGImages.cache'
if os.path.exists(cache):
  os.remove(cache)

from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/home/hejiening/2026/yolo/VOC2012.yaml', epochs=1, imgsz=640, batch=16, device=0)
# Out:
# Ultralytics 8.4.36 🚀 Python-3.8.20 torch-1.9.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...
